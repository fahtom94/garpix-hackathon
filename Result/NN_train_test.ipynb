# %%
import copy
 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import tqdm
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import r2_score

# %%
df = pd.read_csv('loading_data_max.csv')
df=df.drop_duplicates()

X = df.drop(['filling_space_percent','density_percent'], axis=1)
y = df['filling_space_percent']
y
# Out:
# 0      81.72327
# 1      51.56250
# 2      64.24381
# 3      67.29798
# 4      58.26317
#          ...
# 620    76.74275
# 622    83.18305
# 625     0.00248
# 626     0.00496
# 627     0.02481
# Name: filling_space_percent, Length: 510, dtype: float64

# %%
X.shape
# Out:
# (510, 32)

# %%
# train-test split for model evaluation
#X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, shuffle=True)
X_train_raw, X_test_raw, y_train, y_test = train_test_split(X, y, train_size=0.8, shuffle=True,random_state=11)

# Standardizing data
scaler = MinMaxScaler()
scaler.fit(X_train_raw)
X_train = scaler.transform(X_train_raw)
X_test = scaler.transform(X_test_raw)

# Convert to 2D PyTorch tensors
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train.values, dtype=torch.float32).reshape(-1, 1)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_test = torch.tensor(y_test.values, dtype=torch.float32).reshape(-1, 1)

# %%
# Define the model
model = nn.Sequential(
    nn.Linear(32, 500),
    nn.ReLU(),
    nn.Linear(500, 500),
    nn.ReLU(),
    nn.Linear(500, 500),
    nn.ReLU(),
    nn.Linear(500, 1)

)
 
# loss function and optimizer
loss_fn = nn.MSELoss()  # mean square error
optimizer = optim.Adam(model.parameters(), lr=0.0005)

# %%
n_epochs = 4000   # number of epochs to run
batch_size = 510  # size of each batch
batch_start = torch.arange(0, len(X_train), batch_size)
 
# Hold the best model
best_mse = np.inf   # init to infinity
best_weights = None
history = []
 
for epoch in range(n_epochs):
    model.train()
    with tqdm.tqdm(batch_start, unit="batch", mininterval=0, disable=True) as bar:
        bar.set_description(f"Epoch {epoch}")
        for start in bar:
            # take a batch
            X_batch = X_train[start:start+batch_size]
            y_batch = y_train[start:start+batch_size]
            # forward pass
            y_pred = model(X_batch)
            loss = loss_fn(y_pred, y_batch)
            # backward pass
            optimizer.zero_grad()
            loss.backward()
            # update weights
            optimizer.step()
            # print progress
            bar.set_postfix(mse=float(loss))
    # evaluate accuracy at end of each epoch
    model.eval()
    y_pred = model(X_test)
    mse = loss_fn(y_pred, y_test)
    mse = float(mse)
    history.append(mse)
    if mse < best_mse:
        best_mse = mse
        best_weights = copy.deepcopy(model.state_dict())
    if epoch % 50 == 0:
        print(f'Epoch: {epoch} | R^2_NNRegressor: {r2_score(y_test.detach().numpy(), y_pred.detach().numpy()):.4f} MSE:{mse:.4f}')
# Out:
# Epoch: 0 | R^2_NNRegressor: -3.6712 MSE:3041.0681
# Epoch: 50 | R^2_NNRegressor: 0.0592 MSE:612.4881
# Epoch: 100 | R^2_NNRegressor: 0.4483 MSE:359.1954
# Epoch: 150 | R^2_NNRegressor: 0.6904 MSE:201.5855
# Epoch: 200 | R^2_NNRegressor: 0.7786 MSE:144.1210
# Epoch: 250 | R^2_NNRegressor: 0.8227 MSE:115.4469
# Epoch: 300 | R^2_NNRegressor: 0.8373 MSE:105.8927
# Epoch: 350 | R^2_NNRegressor: 0.8439 MSE:101.6155
# Epoch: 400 | R^2_NNRegressor: 0.8485 MSE:98.6369
# Epoch: 450 | R^2_NNRegressor: 0.8543 MSE:94.8545
# Epoch: 500 | R^2_NNRegressor: 0.8606 MSE:90.7408
# Epoch: 550 | R^2_NNRegressor: 0.8657 MSE:87.4269
# Epoch: 600 | R^2_NNRegressor: 0.8700 MSE:84.6158
# Epoch: 650 | R^2_NNRegressor: 0.8743 MSE:81.8453
# Epoch: 700 | R^2_NNRegressor: 0.8771 MSE:79.9941
# Epoch: 750 | R^2_NNRegressor: 0.8790 MSE:78.7721
# Epoch: 800 | R^2_NNRegressor: 0.8829 MSE:76.2666
# Epoch: 850 | R^2_NNRegressor: 0.8864 MSE:73.9812
# Epoch: 900 | R^2_NNRegressor: 0.8886 MSE:72.5446
# Epoch: 950 | R^2_NNRegressor: 0.8916 MSE:70.5907
# Epoch: 1000 | R^2_NNRegressor: 0.8941 MSE:68.9332
# Epoch: 1050 | R^2_NNRegressor: 0.8970 MSE:67.0495
# Epoch: 1100 | R^2_NNRegressor: 0.8995 MSE:65.4310
# Epoch: 1150 | R^2_NNRegressor: 0.9033 MSE:62.9863
# Epoch: 1200 | R^2_NNRegressor: 0.9069 MSE:60.6387
# Epoch: 1250 | R^2_NNRegressor: 0.9109 MSE:57.9967
# Epoch: 1300 | R^2_NNRegressor: 0.9143 MSE:55.7789
# Epoch: 1350 | R^2_NNRegressor: 0.9199 MSE:52.1707
# Epoch: 1400 | R^2_NNRegressor: 0.9247 MSE:49.0504
# Epoch: 1450 | R^2_NNRegressor: 0.9296 MSE:45.8394
# Epoch: 1500 | R^2_NNRegressor: 0.9333 MSE:43.4460
# Epoch: 1550 | R^2_NNRegressor: 0.9378 MSE:40.4630
# Epoch: 1600 | R^2_NNRegressor: 0.9419 MSE:37.8436
# Epoch: 1650 | R^2_NNRegressor: 0.9458 MSE:35.2964
# Epoch: 1700 | R^2_NNRegressor: 0.9490 MSE:33.1827
# Epoch: 1750 | R^2_NNRegressor: 0.9528 MSE:30.7344
# Epoch: 1800 | R^2_NNRegressor: 0.9562 MSE:28.5204
# Epoch: 1850 | R^2_NNRegressor: 0.9598 MSE:26.1686
# Epoch: 1900 | R^2_NNRegressor: 0.9624 MSE:24.5023
# Epoch: 1950 | R^2_NNRegressor: 0.9646 MSE:23.0291
# Epoch: 2000 | R^2_NNRegressor: 0.9662 MSE:21.9997
# Epoch: 2050 | R^2_NNRegressor: 0.9679 MSE:20.8826
# Epoch: 2100 | R^2_NNRegressor: 0.9689 MSE:20.2706
# Epoch: 2150 | R^2_NNRegressor: 0.9705 MSE:19.2116
# Epoch: 2200 | R^2_NNRegressor: 0.9721 MSE:18.1321
# Epoch: 2250 | R^2_NNRegressor: 0.9730 MSE:17.6005
# Epoch: 2300 | R^2_NNRegressor: 0.9753 MSE:16.1055
# Epoch: 2350 | R^2_NNRegressor: 0.9754 MSE:15.9862
# Epoch: 2400 | R^2_NNRegressor: 0.9765 MSE:15.2809
# Epoch: 2450 | R^2_NNRegressor: 0.9771 MSE:14.8833
# Epoch: 2500 | R^2_NNRegressor: 0.9788 MSE:13.8261
# Epoch: 2550 | R^2_NNRegressor: 0.9776 MSE:14.5706
# Epoch: 2600 | R^2_NNRegressor: 0.9799 MSE:13.0771
# Epoch: 2650 | R^2_NNRegressor: 0.9801 MSE:12.9410
# Epoch: 2700 | R^2_NNRegressor: 0.9806 MSE:12.6382
# Epoch: 2750 | R^2_NNRegressor: 0.9806 MSE:12.6305
# Epoch: 2800 | R^2_NNRegressor: 0.9812 MSE:12.2080
# Epoch: 2850 | R^2_NNRegressor: 0.9801 MSE:12.9444
# Epoch: 2900 | R^2_NNRegressor: 0.9817 MSE:11.9174
# Epoch: 2950 | R^2_NNRegressor: 0.9816 MSE:12.0012
# Epoch: 3000 | R^2_NNRegressor: 0.9806 MSE:12.6469
# Epoch: 3050 | R^2_NNRegressor: 0.9828 MSE:11.1882
# Epoch: 3100 | R^2_NNRegressor: 0.9832 MSE:10.9569
# Epoch: 3150 | R^2_NNRegressor: 0.9835 MSE:10.7199
# Epoch: 3200 | R^2_NNRegressor: 0.9838 MSE:10.5607
# Epoch: 3250 | R^2_NNRegressor: 0.9809 MSE:12.4081
# Epoch: 3300 | R^2_NNRegressor: 0.9829 MSE:11.1292
# Epoch: 3350 | R^2_NNRegressor: 0.9841 MSE:10.3395
# Epoch: 3400 | R^2_NNRegressor: 0.9846 MSE:10.0310
# Epoch: 3450 | R^2_NNRegressor: 0.9835 MSE:10.7143
# Epoch: 3500 | R^2_NNRegressor: 0.9850 MSE:9.7867
# Epoch: 3550 | R^2_NNRegressor: 0.9847 MSE:9.9314
# Epoch: 3600 | R^2_NNRegressor: 0.9853 MSE:9.5912
# Epoch: 3650 | R^2_NNRegressor: 0.9841 MSE:10.3446
# Epoch: 3700 | R^2_NNRegressor: 0.9852 MSE:9.6579
# Epoch: 3750 | R^2_NNRegressor: 0.9856 MSE:9.3534
# Epoch: 3800 | R^2_NNRegressor: 0.9859 MSE:9.2104
# Epoch: 3850 | R^2_NNRegressor: 0.9857 MSE:9.3199
# Epoch: 3900 | R^2_NNRegressor: 0.9857 MSE:9.3009
# Epoch: 3950 | R^2_NNRegressor: 0.9863 MSE:8.9402

# %%
# restore model and return best accuracy
model.load_state_dict(best_weights)
print("MSE: %.2f" % best_mse)
print("RMSE: %.2f" % np.sqrt(best_mse))
plt.plot(history)
plt.show()
# Out:
# MSE: 8.81
# RMSE: 2.97

# %%
model.eval()
y_pred = model(X_test)
plt.figure(figsize=(10,10))
y_test=pd.DataFrame(y_test)
y_pred=pd.DataFrame(y_pred.detach().numpy())
print(f'R^2_NNRegressor: {r2_score(y_test, y_pred):.4f} MSE:{mse:.4f}')
sns.regplot(x=y_test, y=y_pred, fit_reg=True, scatter_kws={"s": 100})
# Out:
# R^2_NNRegressor: 0.9865 MSE:8.8298
# <AxesSubplot:xlabel='0', ylabel='0'>
